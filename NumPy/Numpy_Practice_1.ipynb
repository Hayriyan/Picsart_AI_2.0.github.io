# %% [markdown]
# # Numpy exercises

# %% [markdown]
# #### 1. Import the numpy package under the name `np`

# %% [markdown]
# #### 2. Print the numpy version and the configuration

# %% [markdown]
# #### 3. Create a null vector of size 10

# %% [markdown]
# #### 4. How to find the memory size of any array

# %% [markdown]
# #### 6. Create a null vector of size 10 but the fifth value which is 1

# %% [markdown]
# #### 7. Create a vector with values ranging from 10 to 49

# %% [markdown]
# #### 8. Reverse a vector first element becomes last

# %% [markdown]
# #### 9. Create a 3x3 matrix with values ranging from 0 to 8

# %% [markdown]
# #### 11. Create a 3x3 identity matrix

# %% [markdown]
# #### 12. Create a 3x3x3 array with random values

# %% [markdown]
# #### 13. Create a 10x10 array with random values and find the minimum and maximum values

# %% [markdown]
# #### 14. Create a random vector of size 30 and find the mean value

# %% [markdown]
# #### 15. Create a 2d array with 1 on the border and 0 inside

# %% [markdown]
# #### 16. How to add a border filled with 0's around an existing array?

# %% [markdown]
# #### 17. What is the result of the following expression?
# ```python
# 0 * np.nan
# np.nan == np.nan
# np.inf > np.nan
# np.nan - np.nan
# np.nan in (set[np.nan])
# 0.3 == 3 * 0.1
# ```

# %% [markdown]
# #### 18. Create a 5x5 matrix with values 1,2,3,4 just below the diagonal

# %% [markdown]
# #### 19. Create a 8x8 matrix and fill it with a checkerboard pattern

# %% [markdown]
# #### 20. Consider a (6,7,8) shape array, what is the index (x,y,z) of the 100th element?

# %% [markdown]
# #### 22. Normalize a 5x5 random matrix

# %% [markdown]
# #### 24. Multiply a 5x3 matrix by a 3x2 matrix (real matrix product)

# %% [markdown]
# #### 25. Given a 1D array, negate all elements which are between 3 and 8, in place.

# %% [markdown]
# #### 29. How to round away from zero a float array ?

# %% [markdown]
# #### 30. How to find common values between two arrays?

# %% [markdown]
# #### 31. Calculate the element-wise difference between two arrays

# %% [markdown]
# #### 32. Create an array of evenly spaced numbers over a specified interval

# %% [markdown]
# #### 33. Calculate the dot product of two vectors

# %% [markdown]
# #### 34. Find the indices of non-zero elements in an array

# %% [markdown]
# #### 35. Create an array of linearly spaced numbers between two values

# %% [markdown]
# #### 36. How to iterate over the rows of a 2D array?

# %% [markdown]
# #### 42. How to get the nth largest element of an array?

# %% [markdown]
# #### 43. Subtract the mean of each row of a matrix using broadcasting

# %% [markdown]
# #### 44. How to get sorted indices that would sort an array?

# %% [markdown]
# #### 45. How to sum along different axes of a multi-dimensional array?

# %% [markdown]
# #### 46. Create a 2D array from two 1D arrays as rows

# %% [markdown]
# #### 47. Find all elements in an array that are divisible by a given number

# %% [markdown]
# #### 48. Count the number of non-zero elements in an array

# %% [markdown]
# #### 49. Create a structured array with named fields

# %% [markdown]
# #### 50. How to mask an array based on a condition?

# %% [markdown]
# #### 51. Find the nearest value in an array to a given scalar

# %% [markdown]
# #### 52. Create an array with random integers within a specified range

# %% [markdown]
# #### 53. How to flatten a multi-dimensional array?

# %% [markdown]
# #### 54. Calculate the cumulative sum along an axis of an array

# %% [markdown]
# #### 55. How to read and write arrays to disk?

# %% [markdown]
# #### 56. Create a matrix from the Cartesian product of two 1D arrays

# %% [markdown]
# #### 57. How to compute the Euclidean distance between two points?

# %% [markdown]
# #### 60. Create a random permutation of array elements

# %% [markdown]
# #### 61. How to compute the variance and standard deviation of an array?

# %% [markdown]
# #### 62. Find the maximum value along each row of a 2D array

# %% [markdown]
# #### 63. How to compute moving averages of an array?

# %% [markdown]
# #### 64. Create a 3D array and slice it along different dimensions
